# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8')
sns.set_palette('husl')

# %%
# 1. Carregar os dados
df = pd.read_csv('../data/processed_lisboa_porto_air_quality_filtered.csv')
df['datetime'] = pd.to_datetime(df['datetime'], format='%d/%m/%y %H:%M')

# 2. Estatísticas e Missing Values
display(df.describe())
display(df.isnull().sum())
# Out:
#                   datetime           CO          NO2           O3  \
# count                 1442  1442.000000  1442.000000  1442.000000
# mean   2025-09-20 01:00:00     1.006546    29.701477    69.301706
# min    2025-09-05 01:00:00     0.120000     2.420000    28.220000
# 25%    2025-09-12 13:00:00     0.650000    19.040000    56.552500
# 50%    2025-09-20 01:00:00     0.940000    28.155000    69.205000
# 75%    2025-09-27 13:00:00     1.300000    38.527500    81.310000
# max    2025-10-05 01:00:00     2.560000    76.470000   114.680000
# std                    NaN     0.442828    13.279275    16.780429
#
#               PM10        PM2.5          SO2  temperature_c  humidity_percent  \
# count  1442.000000  1442.000000  1442.000000    1442.000000       1442.000000
# mean     21.614896    15.138800     6.453259      19.428502         69.087379
# min       1.840000     0.100000     0.100000      10.000000         16.000000
# ...

# %%
# 3. Distribuição das Variáveis (Histogramas)
numeric_cols = df.select_dtypes(include=[np.number]).columns
numeric_cols = numeric_cols.drop(['year', 'month'], errors='ignore')
df[numeric_cols].hist(bins=20, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
# 4. Matriz de Correlação
plt.figure(figsize=(10, 8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Matriz de Correlações')
plt.show()
